# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3080 Laptop GPU

# %% [markdown]
# # 1. Pre-process

# %% [markdown]
# Load data

# %%
import pandas as pd
import numpy as np
import os
import shutil
import matplotlib.pyplot as plt
import seaborn as sns
import time
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

df = pd.read_csv("dataset/S025_whole_df.csv")
df.head()
# Out:
#    TIMESTAMP     BVP  ACC_X  ACC_Y  ACC_Z   TEMP       EDA    HR  IBI  \
# 0   0.000000  140.76  -40.0    7.0   50.0  33.59  0.034544  60.0  NaN
# 1   0.015625  135.32  -40.0    7.0   50.0  33.59  0.034544  60.0  NaN
# 2   0.031250  130.88  -41.0    7.0   49.0  33.59  0.034544  60.0  NaN
# 3   0.046875  118.15  -41.0    7.0   49.0  33.59  0.034544  60.0  NaN
# 4   0.062500   92.38  -41.0    8.0   50.0  33.59  0.034544  60.0  NaN
#
#   Sleep_Stage  Obstructive_Apnea  Central_Apnea  Hypopnea  Multiple_Events
# 0           P                NaN            NaN       NaN              NaN
# 1           P                NaN            NaN       NaN              NaN
# 2           P                NaN            NaN       NaN              NaN
# 3           P                NaN            NaN       NaN              NaN
# 4           P                NaN            NaN       NaN              NaN

# %% [markdown]
# Clear previous results

# %%
checkpoint_dir = './checkpoints/'

if os.path.exists(checkpoint_dir):
    for item in os.listdir(checkpoint_dir):
        if 'sleep_stage_test' in item:
            dir_path = os.path.join(checkpoint_dir, item)
            shutil.rmtree(dir_path)
            print(f": {dir_path}")

print("Model reseted")

files_to_delete = [
    "X_train.npy", "y_train.npy",
    "X_val.npy", "y_val.npy",
    "X_test.npy", "y_test.npy"
]

save_dir = "./dataset/sleep_data_ready/"
os.makedirs(save_dir, exist_ok=True)
print("Deleteing...")
for file in files_to_delete:
    file_path = os.path.join(save_dir, file)
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f" - Cleaned: {file}")
    else:
        print(f" - skip: {file}")

if os.path.exists('./test_results/'):
    shutil.rmtree('./test_results/')
    print("test_results deleted")
# Out:
# Model reseted
# Deleteing...
#  - Cleaned: X_train.npy
#  - Cleaned: y_train.npy
#  - Cleaned: X_val.npy
#  - Cleaned: y_val.npy
#  - Cleaned: X_test.npy
#  - Cleaned: y_test.npy

# %% [markdown]
# Select Feature and Target, check missing value

# %%
features = ['BVP', 'IBI', 'EDA', 'TEMP', 'ACC_X', 'ACC_Y', 'ACC_Z', 'HR']
label_col = 'Sleep_Stage'

stage_counts = df['Sleep_Stage'].value_counts(dropna=False)
print(stage_counts)

missing_before = df[features].isna().sum().sum()
print(f" Missing Before: {missing_before} ")
# Out:
# Sleep_Stage
# N2    858240
# W     412801
# P     406592
# R     240000
# N1     74880
# Name: count, dtype: int64
#  Missing Before: 2488

# %% [markdown]
# Fill the missing value by taking average of the previous and the next value

# %%
df[features] = df[features].interpolate(method='linear', limit_direction='both')
missing_after = df[features].isna().sum().sum()
print(f"Missing After:{missing_after}")
# Out:
# Missing After:0

# %% [markdown]
# Slice Data

# %%
window_size = 3840
n_samples = len(df) // window_size

X_list = []
y_list = []

for i in range(n_samples):
    start_idx = i * window_size
    end_idx = start_idx + window_size
    
    window_df = df.iloc[start_idx:end_idx]
    
    mode_series = window_df[label_col].mode()
    if mode_series.empty:
        continue
    label = mode_series.iloc[0]
    
    if label in ['P','Missing']:
        continue
        
    downsampled_data = window_df[features].groupby(np.arange(len(window_df)) // 64).mean().values    
    X_list.append(downsampled_data)
    y_list.append(label)

X = np.array(X_list)
y = np.array(y_list)

print("X shape", X.shape) 
print("y shape:", y.shape)
print("Label head", y[:5])
# Out:
# X shape (412, 60, 8)
# y shape: (412,)
# Label head ['W' 'W' 'W' 'W' 'W']

# %%
label_map = {'W': 0, 'N1': 1, 'N2': 2, 'N3': 3, 'R': 4}
y_encoded = np.array([label_map[label] for label in y])

print("label to num head", y_encoded[:5])
# Out:
# label to num head [0 0 0 0 0]

# %% [markdown]
# # 2. Single patient training

# %% [markdown]
# Split and save data

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y_encoded, test_size=0.2, shuffle=False, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.125, shuffle=False, random_state=42)

print(" X_train:", X_train.shape, "y_train:", y_train.shape)
print(" X_val:", X_val.shape, "y_val:", y_val.shape)
print(" X_test:", X_test.shape, "y_test:", y_test.shape)

np.save(os.path.join(save_dir, "X_train.npy"), X_train)
np.save(os.path.join(save_dir, "y_train.npy"), y_train)
np.save(os.path.join(save_dir, "X_val.npy"), X_val)
np.save(os.path.join(save_dir, "y_val.npy"), y_val)
np.save(os.path.join(save_dir, "X_test.npy"), X_test)
np.save(os.path.join(save_dir, "y_test.npy"), y_test)

print(f"Data saved: {save_dir}")
# Out:
#  X_train: (287, 60, 8) y_train: (287,)
#  X_val: (42, 60, 8) y_val: (42,)
#  X_test: (83, 60, 8) y_test: (83,)
# Data saved: ./dataset/sleep_data_ready/

# %% [markdown]
# Train

# %%
# !python -X utf8 run.py \
--task_name classification \
  --is_training 1 \
  --model_id sleep_stage_test \
  --model TimesNet \
  --data sleep \
  --root_path ./dataset/sleep_data_ready/ \
  --seq_len 3840 \
  --enc_in 8 \
  --c_out 5 \
  --batch_size 16 \
  --d_model 32 \
  --d_ff 64 \
  --num_workers 0 \
  --dropout 0.5 \
  --learning_rate 0.00001 \
  --train_epochs 20 \
  --patience 5
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           sleep_stage_test    Model:              TimesNet
#
# Data Loader
#   Data:               sleep               Root Path:          ./dataset/sleep_data_ready/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             8                   Dec In:             7
#   C Out:              5                   d model:            32
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               64
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.5
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        0                   Itr:                1
#   Train Epochs:       20                  Batch Size:         16
#   Patience:           5                   Learning Rate:      1e-05
#   Des:                test                Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 馃殌 Lazy Loading: TimesNet ...
# >>>>>>>start training : classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 1 cost time: 2.3675618171691895
# Epoch: 1, Steps: 18 | Train Loss: 1.909 Vali Loss: 2.133 Vali Acc: 0.048 Test Loss: 1.884 Test Acc: 0.181
# Validation loss decreased (inf --> -0.047619).  Saving model ...
# Epoch: 2 cost time: 1.1516878604888916
# Epoch: 2, Steps: 18 | Train Loss: 1.828 Vali Loss: 2.122 Vali Acc: 0.048 Test Loss: 1.871 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 3 cost time: 1.072012186050415
# Epoch: 3, Steps: 18 | Train Loss: 1.876 Vali Loss: 2.077 Vali Acc: 0.048 Test Loss: 1.854 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 4 cost time: 0.9926903247833252
# Epoch: 4, Steps: 18 | Train Loss: 1.808 Vali Loss: 2.057 Vali Acc: 0.048 Test Loss: 1.832 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 5 cost time: 1.0376083850860596
# Epoch: 5, Steps: 18 | Train Loss: 1.808 Vali Loss: 2.017 Vali Acc: 0.048 Test Loss: 1.808 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 6 cost time: 0.9869410991668701
# Epoch: 6, Steps: 18 | Train Loss: 1.794 Vali Loss: 1.959 Vali Acc: 0.048 Test Loss: 1.783 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 7 cost time: 0.9985933303833008
# Epoch: 7, Steps: 18 | Train Loss: 1.810 Vali Loss: 1.903 Vali Acc: 0.048 Test Loss: 1.754 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 8 cost time: 1.0021257400512695
# Epoch: 8, Steps: 18 | Train Loss: 1.751 Vali Loss: 1.875 Vali Acc: 0.048 Test Loss: 1.724 Test Acc: 0.193
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 9 cost time: 1.0392272472381592
# Epoch: 9, Steps: 18 | Train Loss: 1.737 Vali Loss: 1.815 Vali Acc: 0.048 Test Loss: 1.692 Test Acc: 0.181
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 10 cost time: 1.0429649353027344
# Epoch: 10, Steps: 18 | Train Loss: 1.709 Vali Loss: 1.758 Vali Acc: 0.048 Test Loss: 1.661 Test Acc: 0.205
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 11 cost time: 1.0751945972442627
# Epoch: 11, Steps: 18 | Train Loss: 1.651 Vali Loss: 1.709 Vali Acc: 0.048 Test Loss: 1.627 Test Acc: 0.205
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 12 cost time: 1.060671329498291
# Epoch: 12, Steps: 18 | Train Loss: 1.679 Vali Loss: 1.648 Vali Acc: 0.048 Test Loss: 1.593 Test Acc: 0.193
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 13 cost time: 1.0688493251800537
# Epoch: 13, Steps: 18 | Train Loss: 1.612 Vali Loss: 1.590 Vali Acc: 0.048 Test Loss: 1.557 Test Acc: 0.217
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 14 cost time: 1.0364482402801514
# Epoch: 14, Steps: 18 | Train Loss: 1.585 Vali Loss: 1.542 Vali Acc: 0.048 Test Loss: 1.523 Test Acc: 0.241
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 15 cost time: 1.0161042213439941
# Epoch: 15, Steps: 18 | Train Loss: 1.590 Vali Loss: 1.479 Vali Acc: 0.048 Test Loss: 1.488 Test Acc: 0.241
# Validation loss decreased (-0.047619 --> -0.047619).  Saving model ...
# Epoch: 16 cost time: 1.029503583908081
# Epoch: 16, Steps: 18 | Train Loss: 1.591 Vali Loss: 1.413 Vali Acc: 0.310 Test Loss: 1.452 Test Acc: 0.241
# Validation loss decreased (-0.047619 --> -0.309524).  Saving model ...
# Epoch: 17 cost time: 1.0327131748199463
# Epoch: 17, Steps: 18 | Train Loss: 1.554 Vali Loss: 1.357 Vali Acc: 0.667 Test Loss: 1.418 Test Acc: 0.241
# Validation loss decreased (-0.309524 --> -0.666667).  Saving model ...
# Epoch: 18 cost time: 1.0154995918273926
# Epoch: 18, Steps: 18 | Train Loss: 1.513 Vali Loss: 1.314 Vali Acc: 0.667 Test Loss: 1.385 Test Acc: 0.373
# Validation loss decreased (-0.666667 --> -0.666667).  Saving model ...
# Epoch: 19 cost time: 1.0837714672088623
# Epoch: 19, Steps: 18 | Train Loss: 1.526 Vali Loss: 1.254 Vali Acc: 0.810 Test Loss: 1.350 Test Acc: 0.542
# Validation loss decreased (-0.666667 --> -0.809524).  Saving model ...
# Epoch: 20 cost time: 1.0765998363494873
# Epoch: 20, Steps: 18 | Train Loss: 1.458 Vali Loss: 1.222 Vali Acc: 0.857 Test Loss: 1.321 Test Acc: 0.602
# Validation loss decreased (-0.809524 --> -0.857143).  Saving model ...
# >>>>>>>testing : classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test shape: torch.Size([83, 5]) torch.Size([83])
# accuracy:0.6024096385542169
# Result saved: ./test_results/classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0/

# %% [markdown]
# Graph

# %%
results_dir = './test_results/'
subdirs = [os.path.join(results_dir, d) for d in os.listdir(results_dir) if os.path.isdir(os.path.join(results_dir, d))]
subdirs.sort(key=os.path.getmtime)
latest_subdir = subdirs[-1]

pred_path = os.path.join(latest_subdir, 'pred.npy')
true_path = os.path.join(latest_subdir, 'true.npy')

y_pred = np.load(pred_path)
y_true = np.load(true_path)
if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
    y_pred = np.argmax(y_pred, axis=1)
labels = ['W', 'N1', 'N2', 'N3', 'R']

#Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_true, y_pred)
            
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Sleep Stage Classification Confusion Matrix')
plt.xlabel('Predicted Stage (TimesNet)')
plt.ylabel('True Stage (Doctor)')
plt.show()

# Hypnogram)
clinical_order = [0, 4, 1, 2, 3] # W, R, N1, N2, N3
y_true_clinical = [-clinical_order.index(val) for val in y_true]
y_pred_clinical = [-clinical_order.index(val) for val in y_pred]
clinical_labels = ['W', 'R', 'N1', 'N2', 'N3']


display_length = min(300, len(y_true))
y_true_display = y_true_clinical[:display_length]
y_pred_display = y_pred_clinical[:display_length]

plt.figure(figsize=(14, 5))
            
plt.step(range(display_length), y_true_display, label='True Stage (Doctor)', color='black', linewidth=2.5, where='post')
            
plt.step(range(display_length), [y - 0.1 for y in y_pred_display], label='Predicted (TimesNet)', color='red', linestyle='--', linewidth=2, where='post', alpha=0.8)

plt.yticks([-0, -1, -2, -3, -4], clinical_labels)
plt.title(f'Clinical Hypnogram over Time (First {display_length} Minutes of Test Set)')
plt.xlabel('Time (Minutes)')
plt.ylabel('Sleep Stage')
plt.legend(loc='lower left')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()

# %% [markdown]
# # 3. Cross patient training

# %% [markdown]
# Seleted patient at average for validation and average set

# %%
info_df = pd.read_csv('./dataset/participant_info.csv', dtype=str)
info_df['SID'] = info_df['SID'].astype(str).str.strip()

info_df = info_df.dropna(subset=['SID'])
info_df['SID'] = info_df['SID'].astype(str).str.strip()
info_df = info_df[info_df['SID'].str.lower() != 'nan']
info_df = info_df[info_df['SID'] != '']

features = ['AGE', 'BMI', 'OAHI', 'AHI', 'Mean_SaO2', 'Arousal Index']

if 'Mean_SaO2' in info_df.columns:
    info_df['Mean_SaO2'] = info_df['Mean_SaO2'].astype(str).str.replace('%', '', regex=False)


for col in features:
    info_df[col] = pd.to_numeric(info_df[col], errors='coerce')


global_means = info_df[features].mean()
global_stds = info_df[features].std()

for col in features:
    print(f" - {col}: Mean = {global_means[col]:.2f}, Std = {global_stds[col]:.2f}")


def calculate_multidimensional_distance(row):
    dist_sq = 0
    for col in features:
        if pd.isna(row[col]):
            continue
        z_score = (row[col] - global_means[col]) / global_stds[col]
        dist_sq += z_score ** 2  
    return np.sqrt(dist_sq)

info_df['Distance_to_Centroid'] = info_df.apply(calculate_multidimensional_distance, axis=1)

best_multidim_average = info_df.loc[info_df['Distance_to_Centroid'].idxmin()]

print("\n--- top 5 ---")
top5_candidates = info_df.sort_values(by='Distance_to_Centroid').head(5)
print(top5_candidates[['SID'] + features + ['Distance_to_Centroid']])
# Out:
#  - AGE: Mean = 56.24, Std = 16.56
#  - BMI: Mean = 33.66, Std = 8.58
#  - OAHI: Mean = 19.39, Std = 27.47
#  - AHI: Mean = 22.13, Std = 28.68
#  - Mean_SaO2: Mean = 94.07, Std = 3.13
#  - Arousal Index: Mean = 37.72, Std = 25.69
#
# --- top 5 ---
#      SID    AGE   BMI  OAHI  AHI  Mean_SaO2  Arousal Index  \
# 22  S081  55.35  37.0    17   18         94             32
# 48  S054  60.41  37.0    24   24         93             43
# 87  S014  51.94  32.0    20   21         96             44
# 12  S091  51.01  31.0     9   10         95             38
# 84  S017  58.08  32.0     9   30         96             47
#
#     Distance_to_Centroid
# 22              0.482939
# 48              0.638148
# 87              0.739632
# 12              0.778345
# 84              0.882759

# %%
files_to_delete = [
    "X_train.npy", "y_train.npy",
    "X_val.npy", "y_val.npy",
    "X_test.npy", "y_test.npy"
]

print("Deleting...")
for file in files_to_delete:
    file_path = os.path.join(save_dir, file)
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f" Cleaned: {file}")
    else:
        print(f" - Skip: {file}")
# Out:
# Deleting...
#  Cleaned: X_train.npy
#  Cleaned: y_train.npy
#  Cleaned: X_val.npy
#  Cleaned: y_val.npy
#  Cleaned: X_test.npy
#  Cleaned: y_test.npy

# %% [markdown]
# Declear train set, val set, and test sets

# %%
data_folder = './dataset/' 

#train
train_sids = ['S010', 'S011', 'S028', 'S081']  

#test
val_sid = 'S054'
test_healthy_sid = 'S049'                      
test_severe_sid = 'S046'
test_avg_sid = 'S014'

def process_single_patient(sid, data_dir='./dataset/', window_size=3840):
    print(f"---running on {sid}---")
    file_path = os.path.join(data_dir, f"{sid}_whole_df.csv") 
    
    df = pd.read_csv(file_path)
    
    features_cols = ['BVP', 'IBI', 'EDA', 'TEMP', 'ACC_X', 'ACC_Y', 'ACC_Z', 'HR']
    label_col = 'Sleep_Stage'
    
    missing_before = df[features_cols].isna().sum().sum()
    print(f"Missing before: {missing_before}")
    
    df[features_cols] = df[features_cols].interpolate(method='linear', limit_direction='both')
    
    
    missing_after = df[features_cols].isna().sum().sum()
    print(f"Missing after: {missing_after}") 
    
    scaler = StandardScaler()
    df[features_cols] = scaler.fit_transform(df[features_cols])
    
    return df


print("------test signle------")
df_healthy = process_single_patient(test_healthy_sid)
df_severe = process_single_patient(test_severe_sid)
df_avg = process_single_patient(test_avg_sid)
df_val = process_single_patient(val_sid)
print("------train set------")
train_dfs = {} 

for sid in train_sids:
    train_dfs[sid] = process_single_patient(sid)
# Out:
# ------test signle------
# ---running on S049---
# Missing before: 426
# Missing after: 0
# ---running on S046---
# Missing before: 1283
# Missing after: 0
# ---running on S014---
# Missing before: 3195
# Missing after: 0
# ---running on S054---
# Missing before: 922
# Missing after: 0
# ------train set------
# ---running on S010---
# Missing before: 20211
# Missing after: 0
# ---running on S011---
# Missing before: 657
# Missing after: 0
# ---running on S028---
# Missing before: 289
# Missing after: 0
# ---running on S081---
# Missing before: 2971
# Missing after: 0

# %% [markdown]
# Slice

# %%
def create_windows(df, window_size=3840):
    features_cols = ['BVP', 'IBI', 'EDA', 'TEMP', 'ACC_X', 'ACC_Y', 'ACC_Z', 'HR']
    label_col = 'Sleep_Stage'
    
    n_samples = len(df) // window_size
    X_list = []
    y_list = []
    
    for i in range(n_samples):
        start_idx = i * window_size
        end_idx = start_idx + window_size
        
        window_df = df.iloc[start_idx:end_idx]
        
        mode_series = window_df[label_col].mode()
        if mode_series.empty:
            continue
        label = mode_series.iloc[0]
        
        if str(label).strip() in ['P', 'Missing']:
            continue
            
        downsampled_data = window_df[features_cols].groupby(np.arange(len(window_df)) // 64).mean().values
        
        X_list.append(downsampled_data)
        y_list.append(label)

    return np.array(X_list), np.array(y_list)

print("------ single slice ------")
X_val, y_val = create_windows(df_val)
print(f"val X: {X_val.shape}, y: {y_val.shape}")

X_test_healthy, y_test_healthy = create_windows(df_healthy)
print(f"healthy test X: {X_test_healthy.shape}, y: {y_test_healthy.shape}")

X_test_severe, y_test_severe = create_windows(df_severe)
print(f"severe test X: {X_test_severe.shape}, y: {y_test_severe.shape}")

X_test_avg, y_test_avg = create_windows(df_avg)
print(f"avg test X: {X_test_avg.shape}, y: {y_test_avg.shape}")

print("\n------ group slice ------")
X_train_list = []
y_train_list = []

for sid in train_sids:
    print(f"sclicing data for {sid}...")
    
    clean_df = train_dfs[sid] 
    X_temp, y_temp = create_windows(clean_df)
    
    X_train_list.append(X_temp)
    y_train_list.append(y_temp)

X_train = np.concatenate(X_train_list, axis=0)
y_train = np.concatenate(y_train_list, axis=0)

print(f"\n X_train: {X_train.shape}, y_train: {y_train.shape}")
# Out:
# ------ single slice ------
# val X: (399, 60, 8), y: (399,)
# healthy test X: (397, 60, 8), y: (397,)
# severe test X: (360, 60, 8), y: (360,)
# avg test X: (398, 60, 8), y: (398,)
#
# ------ group slice ------
# sclicing data for S010...
# sclicing data for S011...
# sclicing data for S028...
# sclicing data for S081...
#
#  X_train: (1581, 60, 8), y_train: (1581,)

# %% [markdown]
# Encode data and start testing with average set

# %%
label_map = {'W': 0, 'N1': 1, 'N2': 2, 'N3': 3, 'R': 4}

def encode_labels(y_array, mapping):
    return np.array([mapping[label] for label in y_array])

y_train_encoded = encode_labels(y_train, label_map)
y_val_encoded = encode_labels(y_val, label_map)
y_test_healthy_encoded = encode_labels(y_test_healthy, label_map)
y_test_severe_encoded = encode_labels(y_test_severe, label_map)
y_test_avg_encoded = encode_labels(y_test_avg, label_map)

print(f"lable changed: {y_train_encoded[:5]}")

print("\n------ shape varify ------")
print(f"X_train: {X_train.shape}, y_train: {y_train_encoded.shape}")
print(f"X_val:   {X_val.shape}, y_val:   {y_val_encoded.shape}")
print(f"X_test_healthy: {X_test_healthy.shape}, y_test_healthy: {y_test_healthy_encoded.shape}")
print(f"X_test_severe:  {X_test_severe.shape}, y_test_severe:  {y_test_severe_encoded.shape}")
print(f"X_test_avg:  {X_test_avg.shape}, y_test_avg:  {y_test_avg_encoded.shape}")

#save
save_dir = "./dataset/sleep_data_ready/"
os.makedirs(save_dir, exist_ok=True)

np.save(os.path.join(save_dir, "X_train.npy"), X_train)
np.save(os.path.join(save_dir, "y_train.npy"), y_train_encoded)
np.save(os.path.join(save_dir, "X_val.npy"), X_val)
np.save(os.path.join(save_dir, "y_val.npy"), y_val_encoded)
np.save(os.path.join(save_dir, "X_test.npy"), X_test_avg)
np.save(os.path.join(save_dir, "y_test.npy"), y_test_avg_encoded)


print(f"\nData saved: {save_dir}")
print("ready for training and average test")
# Out:
# lable changed: [0 0 0 0 0]
#
# ------ shape varify ------
# X_train: (1581, 60, 8), y_train: (1581,)
# X_val:   (399, 60, 8), y_val:   (399,)
# X_test_healthy: (397, 60, 8), y_test_healthy: (397,)
# X_test_severe:  (360, 60, 8), y_test_severe:  (360,)
# X_test_avg:  (398, 60, 8), y_test_avg:  (398,)
#
# Data saved: ./dataset/sleep_data_ready/
# ready for training and average test

# %%
def check_label_distribution(y_array, dataset_name):
    counts = Counter(y_array)

    reverse_map = {0: 'W', 1: 'N1', 2: 'N2', 3: 'N3', 4: 'R'}
    
    print(f" --- {dataset_name}  ---")
    total = len(y_array)
    if total == 0:
        print("empty \n")
        return
        
    for num_label in range(5):
        count = counts.get(num_label, 0)
        percentage = (count / total) * 100
        print(f"  {reverse_map[num_label]:<2} ({num_label}): {count:<5} ({percentage:>5.1f}%)")
    print(f" Total: {total} \n")

print("\n Checking Status：\n")
check_label_distribution(y_train_encoded, "Train")
check_label_distribution(y_val_encoded, "Val")
check_label_distribution(y_test_avg_encoded, "Test Avg (S014)")
check_label_distribution(y_test_healthy_encoded, "Test Healthy (S049)")
check_label_distribution(y_test_severe_encoded, "Test Severe (S046)")
# Out:
#  Checking Status：
#
#  --- Train  ---
#   W  (0): 210   ( 13.3%)
#   N1 (1): 243   ( 15.4%)
#   N2 (2): 878   ( 55.5%)
#   N3 (3): 74    (  4.7%)
#   R  (4): 176   ( 11.1%)
#  Total: 1581
#
#  --- Val  ---
#   W  (0): 55    ( 13.8%)
#   N1 (1): 124   ( 31.1%)
#   N2 (2): 208   ( 52.1%)
#   N3 (3): 12    (  3.0%)
#   R  (4): 0     (  0.0%)
#  Total: 399
#
#  --- Test Avg (S014)  ---
#   W  (0): 97    ( 24.4%)
#   N1 (1): 14    (  3.5%)
#   N2 (2): 230   ( 57.8%)
#   N3 (3): 40    ( 10.1%)
#   R  (4): 17    (  4.3%)
#  Total: 398
#
#  --- Test Healthy (S049)  ---
#   W  (0): 64    ( 16.1%)
#   N1 (1): 13    (  3.3%)
#   N2 (2): 277   ( 69.8%)
#   N3 (3): 0     (  0.0%)
#   R  (4): 43    ( 10.8%)
#  Total: 397
#
#  --- Test Severe (S046)  ---
#   W  (0): 82    ( 22.8%)
#   N1 (1): 9     (  2.5%)
#   N2 (2): 216   ( 60.0%)
#   N3 (3): 15    (  4.2%)
#   R  (4): 38    ( 10.6%)
#  Total: 360

# %%
checkpoint_dir = './checkpoints/'

if os.path.exists(checkpoint_dir):
    for item in os.listdir(checkpoint_dir):
        if 'sleep_stage_test' in item:
            dir_path = os.path.join(checkpoint_dir, item)
            shutil.rmtree(dir_path)
            print(f"Removed: {dir_path}")

print("Model Cleaned")

if os.path.exists('./test_results/'):
    shutil.rmtree('./test_results/')
    print("test_results deleted")
# Out:
# Removed: ./checkpoints/classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0
# Model Cleaned
# test_results deleted

# %% [markdown]
# Train1

# %%
#!python -X utf8 run.py --task_name classification --is_training 1 --model_id sleep_stage_test --model TimesNet --data sleep --root_path ./dataset/sleep_data_ready/ --seq_len 3840 --enc_in 8 --c_out 5 --batch_size 16 --d_model 16 --d_ff 32 --num_workers 0

# %%
checkpoint_dir = './checkpoints/'

if os.path.exists(checkpoint_dir):
    for item in os.listdir(checkpoint_dir):
        if 'sleep_stage_test' in item:
            dir_path = os.path.join(checkpoint_dir, item)
            shutil.rmtree(dir_path)
            print(f"Removed: {dir_path}")

print("Model Cleaned")

if os.path.exists('./test_results/'):
    shutil.rmtree('./test_results/')
    print("test_results deleted")
# Out:
# Model Cleaned

# %% [markdown]
# Train2

# %%
#!python -X utf8 run.py --task_name classification --is_training 1 --model_id sleep_stage_test --model TimesNet --data sleep --root_path ./dataset/sleep_data_ready/ --seq_len 3840 --enc_in 8 --c_out 5 --batch_size 16 --d_model 16 --d_ff 32 --num_workers 0 --dropout 0.4 --learning_rate 0.00005 --train_epochs 20 --patience 5

# %%
checkpoint_dir = './checkpoints/'

if os.path.exists(checkpoint_dir):
    for item in os.listdir(checkpoint_dir):
        if 'sleep_stage_test' in item:
            dir_path = os.path.join(checkpoint_dir, item)
            shutil.rmtree(dir_path)
            print(f"Removed: {dir_path}")

print("Model Cleaned")

if os.path.exists('./test_results/'):
    shutil.rmtree('./test_results/')
    print("test_results deleted")
# Out:
# Model Cleaned

# %% [markdown]
# Train3

# %%
# !python -X utf8 run.py \
  --task_name classification \
  --is_training 1 \
  --model_id sleep_stage_test \
  --model TimesNet \
  --data sleep \
  --root_path ./dataset/sleep_data_ready/ \
  --seq_len 3840 \
  --enc_in 8 \
  --c_out 5 \
  --batch_size 16 \
  --d_model 32 \
  --d_ff 64 \
  --num_workers 0 \
  --dropout 0.5 \
  --learning_rate 0.00001 \
  --train_epochs 20 \
  --patience 5
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        1
#   Model ID:           sleep_stage_test    Model:              TimesNet
#
# Data Loader
#   Data:               sleep               Root Path:          ./dataset/sleep_data_ready/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             8                   Dec In:             7
#   C Out:              5                   d model:            32
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               64
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.5
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        0                   Itr:                1
#   Train Epochs:       20                  Batch Size:         16
#   Patience:           5                   Learning Rate:      1e-05
#   Des:                test                Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 馃殌 Lazy Loading: TimesNet ...
# >>>>>>>start training : classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# Epoch: 1 cost time: 7.033802032470703
# Epoch: 1, Steps: 99 | Train Loss: 1.751 Vali Loss: 1.644 Vali Acc: 0.243 Test Loss: 1.636 Test Acc: 0.286
# Validation loss decreased (inf --> -0.243108).  Saving model ...
# Epoch: 2 cost time: 5.788122177124023
# Epoch: 2, Steps: 99 | Train Loss: 1.711 Vali Loss: 1.588 Vali Acc: 0.273 Test Loss: 1.566 Test Acc: 0.324
# Validation loss decreased (-0.243108 --> -0.273183).  Saving model ...
# Epoch: 3 cost time: 5.966604471206665
# Epoch: 3, Steps: 99 | Train Loss: 1.676 Vali Loss: 1.522 Vali Acc: 0.326 Test Loss: 1.487 Test Acc: 0.352
# Validation loss decreased (-0.273183 --> -0.325815).  Saving model ...
# Epoch: 4 cost time: 5.8756256103515625
# Epoch: 4, Steps: 99 | Train Loss: 1.599 Vali Loss: 1.455 Vali Acc: 0.346 Test Loss: 1.406 Test Acc: 0.442
# Validation loss decreased (-0.325815 --> -0.345865).  Saving model ...
# Epoch: 5 cost time: 5.949244260787964
# Epoch: 5, Steps: 99 | Train Loss: 1.545 Vali Loss: 1.395 Vali Acc: 0.338 Test Loss: 1.334 Test Acc: 0.500
# EarlyStopping counter: 1 out of 5
# Epoch: 6 cost time: 5.799811124801636
# Epoch: 6, Steps: 99 | Train Loss: 1.461 Vali Loss: 1.348 Vali Acc: 0.404 Test Loss: 1.274 Test Acc: 0.535
# Validation loss decreased (-0.345865 --> -0.403509).  Saving model ...
# Epoch: 7 cost time: 5.9624388217926025
# Epoch: 7, Steps: 99 | Train Loss: 1.430 Vali Loss: 1.312 Vali Acc: 0.491 Test Loss: 1.232 Test Acc: 0.553
# Validation loss decreased (-0.403509 --> -0.491228).  Saving model ...
# Epoch: 8 cost time: 5.915785789489746
# Epoch: 8, Steps: 99 | Train Loss: 1.377 Vali Loss: 1.291 Vali Acc: 0.509 Test Loss: 1.206 Test Acc: 0.550
# Validation loss decreased (-0.491228 --> -0.508772).  Saving model ...
# Epoch: 9 cost time: 5.956350564956665
# Epoch: 9, Steps: 99 | Train Loss: 1.354 Vali Loss: 1.278 Vali Acc: 0.519 Test Loss: 1.191 Test Acc: 0.563
# Validation loss decreased (-0.508772 --> -0.518797).  Saving model ...
# Epoch: 10 cost time: 5.938080787658691
# Epoch: 10, Steps: 99 | Train Loss: 1.323 Vali Loss: 1.273 Vali Acc: 0.524 Test Loss: 1.186 Test Acc: 0.563
# Validation loss decreased (-0.518797 --> -0.523810).  Saving model ...
# Epoch: 11 cost time: 5.799562454223633
# Epoch: 11, Steps: 99 | Train Loss: 1.317 Vali Loss: 1.270 Vali Acc: 0.524 Test Loss: 1.185 Test Acc: 0.565
# Validation loss decreased (-0.523810 --> -0.523810).  Saving model ...
# Epoch: 12 cost time: 5.879237174987793
# Epoch: 12, Steps: 99 | Train Loss: 1.307 Vali Loss: 1.269 Vali Acc: 0.524 Test Loss: 1.187 Test Acc: 0.568
# Validation loss decreased (-0.523810 --> -0.523810).  Saving model ...
# Epoch: 13 cost time: 5.847155570983887
# Epoch: 13, Steps: 99 | Train Loss: 1.310 Vali Loss: 1.273 Vali Acc: 0.524 Test Loss: 1.190 Test Acc: 0.573
# Validation loss decreased (-0.523810 --> -0.523810).  Saving model ...
# Epoch: 14 cost time: 6.058354616165161
# Epoch: 14, Steps: 99 | Train Loss: 1.276 Vali Loss: 1.274 Vali Acc: 0.524 Test Loss: 1.190 Test Acc: 0.578
# Validation loss decreased (-0.523810 --> -0.523810).  Saving model ...
# Epoch: 15 cost time: 6.30161452293396
# Epoch: 15, Steps: 99 | Train Loss: 1.255 Vali Loss: 1.276 Vali Acc: 0.521 Test Loss: 1.191 Test Acc: 0.590
# EarlyStopping counter: 1 out of 5
# Epoch: 16 cost time: 6.094936847686768
# Epoch: 16, Steps: 99 | Train Loss: 1.266 Vali Loss: 1.280 Vali Acc: 0.514 Test Loss: 1.193 Test Acc: 0.585
# EarlyStopping counter: 2 out of 5
# Epoch: 17 cost time: 5.741244554519653
# Epoch: 17, Steps: 99 | Train Loss: 1.245 Vali Loss: 1.285 Vali Acc: 0.509 Test Loss: 1.196 Test Acc: 0.598
# EarlyStopping counter: 3 out of 5
# Epoch: 18 cost time: 5.597740650177002
# Epoch: 18, Steps: 99 | Train Loss: 1.242 Vali Loss: 1.285 Vali Acc: 0.509 Test Loss: 1.197 Test Acc: 0.608
# EarlyStopping counter: 4 out of 5
# Epoch: 19 cost time: 5.782055854797363
# Epoch: 19, Steps: 99 | Train Loss: 1.249 Vali Loss: 1.293 Vali Acc: 0.509 Test Loss: 1.198 Test Acc: 0.608
# EarlyStopping counter: 5 out of 5
# Early stopping
# >>>>>>>testing : classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test shape: torch.Size([398, 5]) torch.Size([398])
# accuracy:0.5778894472361809
# Result saved: ./test_results/classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0/

# %%
subdirs = [os.path.join(results_dir, d) for d in os.listdir(results_dir) if os.path.isdir(os.path.join(results_dir, d))]
subdirs.sort(key=os.path.getmtime)
latest_subdir = subdirs[-1]

pred_path = os.path.join(latest_subdir, 'pred.npy')
true_path = os.path.join(latest_subdir, 'true.npy')

y_pred = np.load(pred_path)
y_true = np.load(true_path)
if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
    y_pred = np.argmax(y_pred, axis=1)
labels = ['W', 'N1', 'N2', 'N3', 'R']

            
# Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_true, y_pred)
            
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Sleep Stage Classification Confusion Matrix')
plt.xlabel('Predicted Stage (TimesNet)')
plt.ylabel('True Stage (Doctor)')
plt.show()

           
# Hypnogram
clinical_order = [0, 4, 1, 2, 3] # W, R, N1, N2, N3
y_true_clinical = [-clinical_order.index(val) for val in y_true]
y_pred_clinical = [-clinical_order.index(val) for val in y_pred]
clinical_labels = ['W', 'R', 'N1', 'N2', 'N3']

display_length = min(300, len(y_true))
y_true_display = y_true_clinical[:display_length]
y_pred_display = y_pred_clinical[:display_length]

plt.figure(figsize=(14, 5))
            
plt.step(range(display_length), y_true_display, label='True Stage (Doctor)', color='black', linewidth=2.5, where='post')

plt.step(range(display_length), [y - 0.1 for y in y_pred_display], label='Predicted (TimesNet)', color='red', linestyle='--', linewidth=2, where='post', alpha=0.8)

plt.yticks([-0, -1, -2, -3, -4], clinical_labels)
plt.title(f'Clinical Hypnogram over Time (First {display_length} Minutes of Test Set)')
plt.xlabel('Time (Minutes)')
plt.ylabel('Sleep Stage')
plt.legend(loc='lower left')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()

# %% [markdown]
# Test with healthy set

# %%
files_to_delete = [
    "X_test.npy", "y_test.npy"
]

print("Deleting...")
for file in files_to_delete:
    file_path = os.path.join(save_dir, file)
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f" - Cleaned: {file}")
    else:
        print(f" - Skiped: {file}")


np.save(os.path.join(save_dir, "X_test.npy"), X_test_healthy)
np.save(os.path.join(save_dir, "y_test.npy"), y_test_healthy_encoded)
print("ready for healthy test")

if os.path.exists('./test_results/'):
    shutil.rmtree('./test_results/')
    print("test_results deleted")
# Out:
# Deleting...
#  - Cleaned: X_test.npy
#  - Cleaned: y_test.npy
# ready for healthy test
# test_results deleted

# %%
# !python -X utf8 run.py --task_name classification --is_training 0 \
--model_id sleep_stage_test --model TimesNet --data sleep \
--root_path ./dataset/sleep_data_ready/ --seq_len 3840 \
--enc_in 8 --c_out 5 --batch_size 16 --d_model 32 --d_ff 64 --num_workers 0
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        0
#   Model ID:           sleep_stage_test    Model:              TimesNet
#
# Data Loader
#   Data:               sleep               Root Path:          ./dataset/sleep_data_ready/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             8                   Dec In:             7
#   C Out:              5                   d model:            32
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               64
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        0                   Itr:                1
#   Train Epochs:       10                  Batch Size:         16
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                test                Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 馃殌 Lazy Loading: TimesNet ...
# >>>>>>>testing : classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# loading model
# test shape: torch.Size([397, 5]) torch.Size([397])
# accuracy:0.6775818639798489
# Result saved: ./test_results/classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0/

# %%
subdirs = [os.path.join(results_dir, d) for d in os.listdir(results_dir) if os.path.isdir(os.path.join(results_dir, d))]
subdirs.sort(key=os.path.getmtime)
latest_subdir = subdirs[-1]

pred_path = os.path.join(latest_subdir, 'pred.npy')
true_path = os.path.join(latest_subdir, 'true.npy')

y_pred = np.load(pred_path)
y_true = np.load(true_path)
if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
    y_pred = np.argmax(y_pred, axis=1)
labels = ['W', 'N1', 'N2', 'N3', 'R']

            
# Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_true, y_pred)
            
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Sleep Stage Classification Confusion Matrix')
plt.xlabel('Predicted Stage (TimesNet)')
plt.ylabel('True Stage (Doctor)')
plt.show()

           
# Hypnogram
clinical_order = [0, 4, 1, 2, 3] # W, R, N1, N2, N3
y_true_clinical = [-clinical_order.index(val) for val in y_true]
y_pred_clinical = [-clinical_order.index(val) for val in y_pred]
clinical_labels = ['W', 'R', 'N1', 'N2', 'N3']

display_length = min(300, len(y_true))
y_true_display = y_true_clinical[:display_length]
y_pred_display = y_pred_clinical[:display_length]

plt.figure(figsize=(14, 5))
            
plt.step(range(display_length), y_true_display, label='True Stage (Doctor)', color='black', linewidth=2.5, where='post')

plt.step(range(display_length), [y - 0.1 for y in y_pred_display], label='Predicted (TimesNet)', color='red', linestyle='--', linewidth=2, where='post', alpha=0.8)

plt.yticks([-0, -1, -2, -3, -4], clinical_labels)
plt.title(f'Clinical Hypnogram over Time (First {display_length} Minutes of Test Set)')
plt.xlabel('Time (Minutes)')
plt.ylabel('Sleep Stage')
plt.legend(loc='lower left')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()

# %% [markdown]
# Test with severe set

# %%
files_to_delete = [
    "X_test.npy", "y_test.npy"
]

print("Deleting...")
for file in files_to_delete:
    file_path = os.path.join(save_dir, file)
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f" - Cleaned: {file}")
    else:
        print(f" - Skiped: {file}")


np.save(os.path.join(save_dir, "X_test.npy"), X_test_severe)
np.save(os.path.join(save_dir, "y_test.npy"), y_test_severe_encoded)
print("ready for severe test")

if os.path.exists('./test_results/'):
    shutil.rmtree('./test_results/')
    print("test_results deleted")
# Out:
# Deleting...
#  - Cleaned: X_test.npy
#  - Cleaned: y_test.npy
# ready for severe test
# test_results deleted

# %%
# !python -X utf8 run.py --task_name classification --is_training 0 \
--model_id sleep_stage_test --model TimesNet --data sleep \
--root_path ./dataset/sleep_data_ready/ --seq_len 3840 \
--enc_in 8 --c_out 5 --batch_size 16 --d_model 32 --d_ff 64 --num_workers 0
# Out:
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          classification      Is Training:        0
#   Model ID:           sleep_stage_test    Model:              TimesNet
#
# Data Loader
#   Data:               sleep               Root Path:          ./dataset/sleep_data_ready/
#   Data Path:          ETTh1.csv           Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             8                   Dec In:             7
#   C Out:              5                   d model:            32
#   n heads:            8                   e layers:           2
#   d layers:           1                   d FF:               64
#   Moving Avg:         25                  Factor:             1
#   Distil:             1                   Dropout:            0.1
#   Embed:              timeF               Activation:         gelu
#
# Run Parameters
#   Num Workers:        0                   Itr:                1
#   Train Epochs:       10                  Batch Size:         16
#   Patience:           3                   Learning Rate:      0.0001
#   Des:                test                Loss:               MSE
#   Lradj:              type1               Use Amp:            0
#
# GPU
#   Use GPU:            1                   GPU:                0
#   Use Multi GPU:      0                   Devices:            0,1,2,3
#
# De-stationary Projector Params
#   P Hidden Dims:      128, 128            P Hidden Layers:    2
#
# Use GPU: cuda:0
# 馃殌 Lazy Loading: TimesNet ...
# >>>>>>>testing : classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# loading model
# test shape: torch.Size([360, 5]) torch.Size([360])
# accuracy:0.6
# Result saved: ./test_results/classification_sleep_stage_test_TimesNet_sleep_ftM_sl60_ll48_pl0_dm32_nh8_el2_dl1_df64_expand2_dc4_fc1_ebtimeF_dtTrue_test_0/

# %%
subdirs = [os.path.join(results_dir, d) for d in os.listdir(results_dir) if os.path.isdir(os.path.join(results_dir, d))]
subdirs.sort(key=os.path.getmtime)
latest_subdir = subdirs[-1]

pred_path = os.path.join(latest_subdir, 'pred.npy')
true_path = os.path.join(latest_subdir, 'true.npy')

y_pred = np.load(pred_path)
y_true = np.load(true_path)
if len(y_pred.shape) > 1 and y_pred.shape[1] > 1:
    y_pred = np.argmax(y_pred, axis=1)
labels = ['W', 'N1', 'N2', 'N3', 'R']

            
# Confusion Matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_true, y_pred)
            
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Sleep Stage Classification Confusion Matrix')
plt.xlabel('Predicted Stage (TimesNet)')
plt.ylabel('True Stage (Doctor)')
plt.show()

           
# Hypnogram
clinical_order = [0, 4, 1, 2, 3] # W, R, N1, N2, N3
y_true_clinical = [-clinical_order.index(val) for val in y_true]
y_pred_clinical = [-clinical_order.index(val) for val in y_pred]
clinical_labels = ['W', 'R', 'N1', 'N2', 'N3']

display_length = min(300, len(y_true))
y_true_display = y_true_clinical[:display_length]
y_pred_display = y_pred_clinical[:display_length]

plt.figure(figsize=(14, 5))
            
plt.step(range(display_length), y_true_display, label='True Stage (Doctor)', color='black', linewidth=2.5, where='post')

plt.step(range(display_length), [y - 0.1 for y in y_pred_display], label='Predicted (TimesNet)', color='red', linestyle='--', linewidth=2, where='post', alpha=0.8)

plt.yticks([-0, -1, -2, -3, -4], clinical_labels)
plt.title(f'Clinical Hypnogram over Time (First {display_length} Minutes of Test Set)')
plt.xlabel('Time (Minutes)')
plt.ylabel('Sleep Stage')
plt.legend(loc='lower left')
plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
